# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('house_rental_data.csv.txt')
data
# Out:
#      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0             1  1177.698      2           7        2            2         2
# 1             2  2134.800      5           7        4            2         2
# 2             3  1138.560      5           7        2            2         1
# 3             4  1458.780      2           7        3            2         2
# 4             5   967.776     11          14        3            2         2
# ..          ...       ...    ...         ...      ...          ...       ...
# 640         644  1359.156      7          15        3            2         2
# 641         645   377.148      4          10        1            1         1
# 642         646   740.064     13          14        1            1         1
# 643         647  1707.840      3          14        3            2         2
# 644         648  1376.946      6           7        3            2         1
#
#      Price
# 0    62000
# 1    78000
# 2    58000
# 3    45000
# 4    45000
# ..     ...
# 640  45000
# 641  24800
# 642  45000
# 643  65000
# 644  36000
#
# [645 rows x 8 columns]

# %%
np.shape(data)
# Out:
# (645, 8)

# %%
data.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0           1  1177.698      2           7        2            2         2
# 1           2  2134.800      5           7        4            2         2
# 2           3  1138.560      5           7        2            2         1
# 3           4  1458.780      2           7        3            2         2
# 4           5   967.776     11          14        3            2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
data.tail()
# Out:
#      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 640         644  1359.156      7          15        3            2         2
# 641         645   377.148      4          10        1            1         1
# 642         646   740.064     13          14        1            1         1
# 643         647  1707.840      3          14        3            2         2
# 644         648  1376.946      6           7        3            2         1
#
#      Price
# 640  45000
# 641  24800
# 642  45000
# 643  65000
# 644  36000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   645 non-null    int64
#  1   Sqft         645 non-null    float64
#  2   Floor        645 non-null    int64
#  3   TotalFloor   645 non-null    int64
#  4   Bedroom      645 non-null    int64
#  5   Living.Room  645 non-null    int64
#  6   Bathroom     645 non-null    int64
#  7   Price        645 non-null    int64
# dtypes: float64(1), int64(7)
# memory usage: 40.4 KB

# %%
data.describe()
# Out:
#        Unnamed: 0         Sqft       Floor  TotalFloor     Bedroom  \
# count  645.000000   645.000000  645.000000  645.000000  645.000000
# mean   325.159690  1527.656260    5.939535   10.855814    2.837209
# std    187.312152   767.386531    3.884721    4.996208    1.010740
# min      1.000000   359.358000    1.000000    1.000000    1.000000
# 25%    164.000000   925.080000    3.000000    7.000000    2.000000
# 50%    326.000000  1423.200000    5.000000   12.000000    3.000000
# 75%    487.000000  1892.856000    8.000000   14.000000    4.000000
# max    648.000000  5856.468000   22.000000   38.000000    7.000000
#
#        Living.Room    Bathroom          Price
# count   645.000000  645.000000     645.000000
# mean      1.813953    1.810853   61986.823256
# std       0.462364    0.683574   35635.091007
# min       0.000000    0.000000    6100.000000
# 25%       2.000000    1.000000   39000.000000
# 50%       2.000000    2.000000   50000.000000
# 75%       2.000000    2.000000   75000.000000
# max       4.000000    5.000000  250000.000000

# %%
data.columns.values
# Out:
# array(['Unnamed: 0', 'Sqft', 'Floor', 'TotalFloor', 'Bedroom',
#        'Living.Room', 'Bathroom', 'Price'], dtype=object)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Sqft           0
# Floor          0
# TotalFloor     0
# Bedroom        0
# Living.Room    0
# Bathroom       0
# Price          0
# dtype: int64

# %%
data = data.drop('Unnamed: 0',axis = 1)

# %%
data.astype(int)
# Out:
#      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 0    1177      2           7        2            2         2  62000
# 1    2134      5           7        4            2         2  78000
# 2    1138      5           7        2            2         1  58000
# 3    1458      2           7        3            2         2  45000
# 4     967     11          14        3            2         2  45000
# ..    ...    ...         ...      ...          ...       ...    ...
# 640  1359      7          15        3            2         2  45000
# 641   377      4          10        1            1         1  24800
# 642   740     13          14        1            1         1  45000
# 643  1707      3          14        3            2         2  65000
# 644  1376      6           7        3            2         1  36000
#
# [645 rows x 7 columns]

# %%
plt.scatter(data['Sqft'],data['Price'])
plt.xlabel('Sqft')
plt.ylabel('Price')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
X = data.drop('Price',axis = 1)
X
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom
# 0    1177.698      2           7        2            2         2
# 1    2134.800      5           7        4            2         2
# 2    1138.560      5           7        2            2         1
# 3    1458.780      2           7        3            2         2
# 4     967.776     11          14        3            2         2
# ..        ...    ...         ...      ...          ...       ...
# 640  1359.156      7          15        3            2         2
# 641   377.148      4          10        1            1         1
# 642   740.064     13          14        1            1         1
# 643  1707.840      3          14        3            2         2
# 644  1376.946      6           7        3            2         1
#
# [645 rows x 6 columns]

# %%
y = data['Price']
y
# Out:
# 0      62000
# 1      78000
# 2      58000
# 3      45000
# 4      45000
#        ...
# 640    45000
# 641    24800
# 642    45000
# 643    65000
# 644    36000
# Name: Price, Length: 645, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.20, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors = 7)
knn
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
y_pred = knn.predict(X_test)
y_pred
# Out:
# array([ 42257.14285714,  42257.14285714,  57142.85714286,  42571.42857143,
#         95428.42857143,  64269.71428571,  91142.85714286,  91285.57142857,
#         68428.57142857,  34785.57142857,  58555.42857143,  38269.71428571,
#         42928.57142857,  41285.71428571,  28555.42857143,  81285.71428571,
#         56160.        ,  37785.71428571,  46142.85714286,  33571.42857143,
#         51142.85714286,  45571.42857143,  40571.42857143, 201571.42857143,
#        175571.42857143,  46071.42857143,  62571.42857143,  36971.42857143,
#         34714.28571429,  38428.57142857,  44657.14285714,  90142.85714286,
#         74999.85714286,  51142.85714286,  38269.71428571,  60828.57142857,
#         95000.        ,  63571.42857143,  72214.14285714,  72285.71428571,
#         63285.71428571, 167000.        ,  81285.71428571,  95000.        ,
#         45671.28571429,  51857.14285714,  32928.42857143,  43146.57142857,
#         63200.        ,  32585.57142857,  48285.57142857,  68428.57142857,
#        192285.71428571,  72285.71428571,  63571.42857143,  68428.57142857,
#        104571.28571429,  37142.85714286,  77857.        ,  79142.85714286,
#         85142.71428571, 135428.42857143,  91142.85714286,  55142.85714286,
#         89571.28571429,  38000.        ,  32928.42857143,  35433.14285714,
#         28555.42857143,  57142.85714286,  28785.71428571,  32928.42857143,
#         31286.        ,  28555.42857143,  66571.28571429,  35261.42857143,
#         75714.        ,  48500.        ,  46000.        ,  46428.57142857,
#         66571.28571429,  83428.42857143,  42928.57142857,  31928.85714286,
#         45671.28571429,  25785.71428571, 135428.42857143, 101269.71428571,
#         51857.14285714,  42003.85714286,  81285.71428571, 101269.71428571,
#         35071.28571429, 130857.14285714,  25714.28571429,  35433.14285714,
#         44657.14285714,  51142.85714286,  35285.57142857, 136857.        ,
#         51142.85714286, 175571.42857143,  64428.28571429, 105428.42857143,
#         37142.85714286,  37657.14285714,  33143.14285714,  42928.57142857,
#         81714.14285714,  66285.71428571,  44657.14285714,  40899.71428571,
#         42257.14285714,  33571.42857143,  37928.57142857,  61000.        ,
#         36971.42857143,  54159.85714286,  31286.        ,  90142.85714286,
#         52126.85714286,  63571.42857143,  38428.57142857,  83857.        ,
#         42861.14285714,  32585.57142857,  69285.71428571,  37142.85714286,
#         91285.57142857])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.735966176726123
